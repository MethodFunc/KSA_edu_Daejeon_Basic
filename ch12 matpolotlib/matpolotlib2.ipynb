# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import random as rd
# 화면에 그래프 그리기
# %matplotlib inline
# Korean Setting , Minus 표시
mpl.rcParams['axes.unicode_minus'] = False
# family = 폰트 이름 size = 사이즈 크기
mpl.rc('font', family='D2Coding', size=25)
# Graph 크기 변경
plt.rcParams["figure.figsize"]= (15,9)

# %%
# 12-7
x = ['영희', '철수', '재호']
y = [3, 1, 5]

plt.title('연간 영화관람 회수')
plt.bar(x, y)
plt.ylabel('회수')
plt.show()

# %%
# 12-7
x = ['영희', '철수', '재호']
y = [3, 1, 5]

plt.title('연간 영화관람 회수')
plt.barh(x, y)
plt.xlabel('회수')
plt.show()

# %%
np.random.seed(1000)
data = np.random.randn(100)
plt.hist(data, bins=10)
plt.show()

# %%
n, bins, patches = plt.hist(data, bins=10)

# %%
n
# Out:
# array([ 2.,  3., 10., 17., 22., 16., 17.,  7.,  3.,  3.])

# %%
bins
# Out:
# array([-2.68159245, -2.12725629, -1.57292012, -1.01858396, -0.4642478 ,
#         0.09008836,  0.64442453,  1.19876069,  1.75309685,  2.30743301,
#         2.86176918])

# %%
patches
# Out:
# <a list of 10 Patch objects>

# %%
# 산점도 (scatter) 12-8
x = ['월', '화', '수', '목', '금', '토', '일']
y = [6.5, 5.7, 5.5, 6.7, 6.3, 7.5, 8.3]
plt.title('연간 요일별 평균 수면 시간')
plt.scatter(x, y, color='r', lineWidth = 5)
plt.ylabel('수면시간')
plt.show()

# %%
# 두개의 그룹 그래프 그리기
np.random.seed(1000)
x1_data= np.random.randn(100)
y1_data = np.random.randn(100)
# 정규 분포
x2_data = np.random.normal(3, 2, 100)
y2_data = np.random.normal(3, 2, 100)
# 균등분포
x3_data = np.random.uniform(5, 2, 100)
y3_data = np.random.uniform(5, 2, 100)

plt.scatter(x1_data, y1_data, label='N(0, 1)')
plt.scatter(x2_data, y2_data, label='N(3, 2)')
plt.scatter(x3_data, y3_data, label='N(5, 2)')

plt.legend(loc='best')
plt.show()

# %%
# 12-9

pets=['개', '고양이', '기타', '기르지않음']
portion = [18, 3.4, 3.1, 75.5]

plt.pie(portion, explode = (0.3, 0.3, 0.3, 0), labels=pets, autopct='%1.1f%%', shadow=True, startangle = 90)

plt.show()

# %%
plt.pie(portion, explode = (0.3, 0.3, 0.3, 0), labels=pets, autopct='%1.1f%%', shadow=True, startangle = 0)

plt.show()

# %%
plt.pie(portion, explode = (0.3, 0.3, 0.3, 0), labels=pets, autopct='%1.1f%%', shadow=True, startangle = 180)

plt.show()

# %%
plt.pie(portion, explode = (0.3, 0.3, 0.3, 0), labels=pets, autopct='%1.1f%%', shadow=True, startangle = 270)

plt.show()

# %%
# Q 12-1
data = list(range(1,11))
min_temp = [7.3,3.5,7.2,4.5,3.5,8.3,7.7,6.4,9.3,6.3]
max_temp = [15,16.3,15.2,17.5,18.3,20.0,18.8,17.5,14.2,15.3]

plt.plot(data, min_temp, 'ro-',label='Min Temparature')
plt.plot(data, max_temp, 'bx-.',label='Max Temparature')

plt.xlabel('data')
plt.ylabel('Temparature')
plt.title('Min and Max temparature of ten days')
plt.legend(loc='best')

plt.show()

# %%
# Q 12-2
x_data = ['안지영', '홍지수', '황예린']
y1_data = [90, 85, 88]
y2_data = [83, 88, 91]
y3_data = [85, 97, 78]
y4_data = [92, 88, 82]

plt.plot(x_data, y1_data, 'r*--',label='국어')
plt.plot(x_data, y2_data, 'gs-',label='영어')
plt.plot(x_data, y3_data, 'bd:',label='수학')
plt.plot(x_data, y4_data, 'co-.',label='사회')

plt.ylim(0, 100)
plt.ylabel('점수')
plt.title('세 학생의 네 과목 성적')

plt.legend(loc='best')

plt.show()

# %%
# Q 12-3
def make_random_list(num):
    result =[]
    for i in range(num):
        result.append(rd.randrange(1, 7))
    return result

count = 10
y = make_random_list(count)
x = list(range(1, 11))

plt.title('주사위 10회 던지기')
plt.bar(x, y)
plt.xticks(x)
plt.yticks([1,2,3,4,5,6])
plt.xlabel('던진 횟수')
plt.ylabel('주사위 눈')

plt.show()

# %%
x = np.linspace(0.1, 2 * np.pi, 10)
plt.title("Stem Plot")
plt.stem(x, np.cos(x), '-.',use_line_collection = True)
plt.show()

# %%
# Imshow
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[9]
plt.title("mnist digits; 9")
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %%
# bubble chart
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %%
# 3D 서피스 플롯
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, ZZ, rstride=1, cstride=1, cmap='hot')
plt.show()

# %%
# 컨투어 플롯
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)


n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

plt.title("Contour plots")
plt.contourf(XX, YY, ZZ, alpha=.55, cmap='jet') #Alpha = 투명도
plt.contour(XX, YY, ZZ, colors='black')
plt.show()

# %%
from math import pi
import matplotlib.pyplot as plt


# Set data
cat = ['Speed', 'Reliability', 'Comfort', 'Safety', 'Effieciency']
values = [90, 60, 65, 70, 40]

N = len(cat)

x_as = [n / float(N) * 2 * pi for n in range(N)]

# Because our chart will be circular we need to append a copy of the first 
# value of each list at the end of each list with data
values += values[:1]
x_as += x_as[:1]


# Set color of axes
plt.rc('axes', linewidth=0.5, edgecolor="#888888")


# Create polar plot
ax = plt.subplot(111, polar=True)


# Set clockwise rotation. That is:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)


# Set position of y-labels
ax.set_rlabel_position(0)


# Set color and linestyle of grid
ax.xaxis.grid(True, color="#888888", linestyle='solid', linewidth=0.5)
ax.yaxis.grid(True, color="#888888", linestyle='solid', linewidth=0.5)


# Set number of radial axes and remove labels
plt.xticks(x_as[:-1], [])

# Set yticks
plt.yticks([20, 40, 60, 80, 100], ["20", "40", "60", "80", "100"])


# Plot data
ax.plot(x_as, values, linewidth=0, linestyle='solid', zorder=3)

# Fill area
ax.fill(x_as, values, 'b', alpha=0.3)


# Set axes limits
plt.ylim(0, 100)


# Draw ytick labels to make sure they fit properly
for i in range(N):
       angle_rad = i / float(N) * 2 * pi

       if angle_rad == 0:
           ha, distance_ax = "center", 10
       elif 0 < angle_rad < pi:
           ha, distance_ax = "left", 1
       elif angle_rad == pi:
           ha, distance_ax = "center", 1
       else:
           ha, distance_ax = "right", 1

       ax.text(angle_rad, 100 + distance_ax, cat[i], size=10, horizontalalignment=ha, verticalalignment="center")


# Show polar plot
plt.show()
