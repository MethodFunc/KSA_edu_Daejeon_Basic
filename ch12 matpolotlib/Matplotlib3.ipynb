# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import csv
# 화면에 그래프 그리기
# %matplotlib inline
# Korean Setting , Minus 표시
mpl.rcParams['axes.unicode_minus'] = False
# family = 폰트 이름 size = 사이즈 크기
mpl.rc('font', family='D2Coding', size=12)
# Graph 크기 변경
plt.rcParams["figure.figsize"]= (15,9)

# %% [markdown]
# # 그래프 여러개 그리기

# %%
# 12-10

x = ['월', '화', '수', '목', '금', '토', '일']
y1 = [6.5, 5.7, 5.5, 6.7, 6.3, 7.5, 8.3]
y2 = [6.3, 7.7, 7.5, 7.3, 6.2, 7.3, 8.5]



fig, axs= plt.subplots(nrows=1, ncols=2, figsize=(9,3), sharex=True, sharey=True)

ax = axs[0]
ax.scatter(x, y1)
ax.set_title('2018')

ax = axs[1]
ax.scatter(x, y2)
ax.set_title('2019')

fig.suptitle('연간 요일별 평균 수면시간')
plt.show()

# %%
# 12-10

x = ['월', '화', '수', '목', '금', '토', '일']
y1 = [6.5, 5.7, 5.5, 6.7, 6.3, 7.5, 8.3]
y2 = [6.3, 7.7, 7.5, 7.3, 6.2, 7.3, 8.5]
y3 = [6.7, 7.9, 5.5, 7.2, 7.2, 8.3, 9.5]
y4 = [6.8, 6.7, 3.5, 7.7, 6.2, 7.3, 8.5]



fig, axs= plt.subplots(nrows=2, ncols=2, figsize=(9,6), sharex=True, sharey=True)

ax = axs[0][0]
ax.scatter(x, y1)
ax.set_title('2016')

ax = axs[0][1]
ax.scatter(x, y2)
ax.set_title('2017')

ax = axs[1][0]
ax.scatter(x, y3)
ax.set_title('2018')

ax = axs[1][1]
ax.bar(x, y4)
ax.set_title('2019')



fig.suptitle('연간 요일별 평균 수면시간')
plt.show()

# %%
# 12-11
x =list(range(1, 11))
y = list(range(10, 101, 10))

fig, axs= plt.subplots(nrows=2, ncols=2, figsize=(9,5), sharex=True, sharey=True)

ax = axs[0][0]
ax.plot(x, y)
ax.set_title('Line1')

ax = axs[0][1]
ax.plot(x, y, 'ro--')
ax.set_title('Line2')

ax = axs[1][0]
ax.bar(x, y)
ax.set_title('Bar')

ax = axs[1][1]
ax.scatter(x, y)
ax.set_title('Scatter')

# 그래프 간격 조절
plt.subplots_adjust(left=0.1,right=0.9,bottom=0.1,top=0.95,wspace=0.2,hspace=0.3)
plt.show()

# %%
import seaborn as sns
ans = sns.load_dataset('anscombe')

# %%
ans.shape
# Out:
# (44, 3)

# %%
ans.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
ans.tail()
# Out:
#    dataset     x      y
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
ans.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
ds1 = ans[ans['dataset'] == 'I']
ds2 = ans[ans['dataset'] == 'II']
ds3 = ans[ans['dataset'] == 'III']
ds4 = ans[ans['dataset'] == 'IV']

# %%
ds1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# 11개의 점을 그림
axes1.plot(ds1['x'], ds1['y'], 'o')
axes2.plot(ds2['x'], ds2['y'], 'o')           
axes3.plot(ds3['x'], ds3['y'], 'o')           
axes4.plot(ds4['x'], ds4['y'], 'o')

# y = 3 + 1 / 2 * x 의 직선을 그림
axes1.plot([0,20], [3,13], 'r-', lw=2)
axes2.plot([0,20], [3,13], 'r-', lw=2)
axes3.plot([0,20], [3,13], 'r-', lw=2)
axes4.plot([0,20], [3,13], 'r-', lw=2)

# x 축을 0 ~ 20까지 그리고 y축을 2~14까지 그린다.
axes1.set(xlim=(0,20), ylim=(2,14))
axes2.set(xlim=(0,20), ylim=(2,14))
axes3.set(xlim=(0,20), ylim=(2,14))
axes4.set(xlim=(0,20), ylim=(2,14))

axes1.set(xticks=range(0,21,2), yticks=range(2,15,2))
axes2.set(xticks=range(0,21,2), yticks=range(2,15,2))
axes3.set(xticks=range(0,21,2), yticks=range(2,15,2))
axes4.set(xticks=range(0,21,2), yticks=range(2,15,2))

axes1.set_title('Dataset 1')
axes2.set_title('Dataset 2')
axes3.set_title('Dataset 3')
axes4.set_title('Dataset 4')

plt.show()

# %% [markdown]
# ## Refactoring

# %%
ds = []
ds.append(ans[ans['dataset'] == 'I'])
ds.append(ans[ans['dataset'] == 'II'])
ds.append(ans[ans['dataset'] == 'III'])
ds.append(ans[ans['dataset'] == 'IV'])

# %%
fig, axs = plt.subplots(2, 2, figsize = (12,10))

for i in range(len(ds)):
    axs[i//2][i%2].plot(ds[i]['x'], ds[i]['y'], 'o')
    axs[i//2][i%2].plot([0,20], [3,13], 'r-', lw=2)
    axs[i//2][i%2].set(xlim=(0,20), ylim=(2,14))   
    axs[i//2][i%2].set(xticks=range(0,21,2), yticks=range(2,15,2))
    axs[i//2][i%2].set_title('Dataset '+ str(i+1)) 
    
fig.suptitle("Anscombe's Quartet")
plt.subplots_adjust(left=0.1,right=0.9,bottom=0.1,top=0.95,wspace=0.2,hspace=0.3)
plt.show()

# %% [markdown]
# ## Seaborn graph

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris, hue="species", markers=['o', 's',  'D'])
plt.title('Iris Pair Plot, Hue로 꽃의 종을 시각화')
plt.show()
